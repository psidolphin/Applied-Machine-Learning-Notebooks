# %% [markdown]
# ## SPRING 2021
# ## Applied Machine Learning
# ### Practicum 5: Feature Engineering. Solutions.

# %%
import numpy as np
import pandas as pd
from seaborn import load_dataset

df=load_dataset('titanic')
spam=pd.read_csv('https://raw.githubusercontent.com/graf10a/Applied-Machine-Learning-Course/main/Data/spam.csv', 
                 encoding = "ISO-8859-1")[['v1', 'v2']]
