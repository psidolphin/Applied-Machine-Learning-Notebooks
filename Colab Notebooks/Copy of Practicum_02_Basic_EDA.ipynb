# %% [markdown]
# ## SPRING 2021
# ## Applied Machine Learning
# ### Practicum 2: The basics EDA and logistic regression.
#
# Download and pre-process the Iris flower data set by running the code cell below.

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris

iris_data=load_iris()
iris = pd.DataFrame(data=iris_data['data'], columns=[col[:-5] for col in iris_data['feature_names']])
iris['target']=iris_data['target']

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width  target
# 0           5.1          3.5           1.4          0.2       0
# 1           4.9          3.0           1.4          0.2       0
# 2           4.7          3.2           1.3          0.2       0
# 3           4.6          3.1           1.5          0.2       0
# 4           5.0          3.6           1.4          0.2       0

# %%
iris.isna().head()
# Out:
#    sepal length  sepal width  petal length  petal width  target
# 0         False        False         False        False   False
# 1         False        False         False        False   False
# 2         False        False         False        False   False
# 3         False        False         False        False   False
# 4         False        False         False        False   False

# %%
iris.isna().sum()
# Out:
# sepal length    0
# sepal width     0
# petal length    0
# petal width     0
# target          0
# dtype: int64

# %%
iris.isna().sum().sum()
# Out:
# 0

# %%
iris['target'].value_counts()    
#This is the number of observations for each classification
# Out:
# 2    50
# 1    50
# 0    50
# Name: target, dtype: int64

# %%
unq = iris['target'].unique()

# %%
unq
# Out:
# array([0, 1, 2])

# %%
iris_data['target_names']
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
import seaborn as sns #extension of matplotlib


sns.pairplot(iris, hue='target', palette={0:'red', 1:'blue', 2: 'green'}, diag_kind='hist')
