# %% [markdown]
# ## SPRING 2021
# ## Applied Machine Learning
# ### Practicum 5: Feature Engineering.

# %%
import numpy as np
import pandas as pd
from seaborn import load_dataset

df=load_dataset('titanic')
spam=pd.read_csv('https://raw.githubusercontent.com/graf10a/Applied-Machine-Learning-Course/main/Data/spam.csv', 
                 encoding = "ISO-8859-1")[['v1', 'v2']]

# %%
df.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
#double check the adult_male column
df['adult_male'].unique()
# Out:
# array([ True, False])

# %%
df['adult_male_int'] = df['adult_male'].values.astype(np.uint8)

df[['adult_male', 'adult_male_int']].head()
# Out:
#    adult_male  adult_male_int
# 0        True               1
# 1       False               0
# 2       False               0
# 3       False               0
# 4        True               1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   survived        891 non-null    int64
#  1   pclass          891 non-null    int64
#  2   sex             891 non-null    object
#  3   age             714 non-null    float64
#  4   sibsp           891 non-null    int64
#  5   parch           891 non-null    int64
#  6   fare            891 non-null    float64
#  7   embarked        889 non-null    object
#  8   class           891 non-null    category
#  9   who             891 non-null    object
#  10  adult_male      891 non-null    bool
#  11  deck            203 non-null    category
#  12  embark_town     889 non-null    object
#  13  alive           891 non-null    object
#  14  alone           891 non-null    bool
#  15  adult_male_int  891 non-null    uint8
# ...

# %%
df.drop(labels=['deck'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone', 'adult_male_int'],
#       dtype='object')

# %%
df.dropna(inplace=True)
df.isna().sum().sum()
# Out:
# 0

# %%
#converting the alive column to numerical form
df['alive_int'] = (df['alive']=='yes').astype(np.uint8)
df[ ['survived','alive', 'alive_int'] ].head()
# Out:
#    survived alive  alive_int
# 0         0    no          0
# 1         1   yes          1
# 2         1   yes          1
# 3         1   yes          1
# 4         0    no          0

# %%
np.equal(df['survived'].values, df['alive_int'].values).sum()
# Out:
# 712

# %%
#Using the special scikit label encoder class
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['alive_le'] = le.fit_transform(df['alive'])

le.classes_
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df[ ['survived','alive', 'alive_int', 'alive_le'] ].head()
# Out:
#    survived alive  alive_int  alive_le
# 0         0    no          0         0
# 1         1   yes          1         1
# 2         1   yes          1         1
# 3         1   yes          1         1
# 4         0    no          0         0

# %%
from sklearn.preprocessing import OrdinalEncoder

oe = OrdinalEncoder(dtype=np.uint8)

# %%
cat_feats=['who', 'embark_town']
cat_feats_int = [feat + '_int' for feat in cat_feats]

# %%
df[cat_feats_int] = oe.fit_transform(df[cat_feats])

# %%
df[cat_feats+cat_feats_int].head()
# Out:
#      who  embark_town  who_int  embark_town_int
# 0    man  Southampton        1                2
# 1  woman    Cherbourg        2                0
# 2  woman  Southampton        2                2
# 3  woman  Southampton        2                2
# 4    man  Southampton        1                2

# %%
oe.categories_
# Out:
# [array(['child', 'man', 'woman'], dtype=object),
#  array(['Cherbourg', 'Queenstown', 'Southampton'], dtype=object)]

# %%
#one hot encoding

one_hot = pd.get_dummies(df[cat_feats])

one_hot.head()
# Out:
#    who_child  who_man  ...  embark_town_Queenstown  embark_town_Southampton
# 0          0        1  ...                       0                        1
# 1          0        0  ...                       0                        0
# 2          0        0  ...                       0                        1
# 3          0        0  ...                       0                        1
# 4          0        1  ...                       0                        1
#
# [5 rows x 6 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

oh = OneHotEncoder(dtype=np.uint8)

df_oh= oh.fit_transform(df[cat_feats])

# %%
#Column Transformer creates a pipeline stack

#a pipeline of piplines





from sklearn.feature_extraction.text import TfidfTransformer

sample = [
          'mencken',
          'bruce',
          'krassner'
]

#the sample array is referred to as a corpus
#every single word in a document is referred to as a term
vec = TfidfTransformer()

X = vec.fit_transform(sample)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-f66ea14f468b> in <module>()
#      17 vec = TfidfTransformer()
#      18
# ---> 19 X = vec.fit_transform(sample)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py in fit(self, X, y)
#    1448             a matrix of term/token counts
#    1449         """
# -> 1450         X = check_array(X, accept_sparse=('csr', 'csc'))
#    1451         if not sp.issparse(X):
#    1452             X = sp.csr_matrix(X)
#
# ...
